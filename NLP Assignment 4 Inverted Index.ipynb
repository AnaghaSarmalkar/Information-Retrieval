# %% [markdown]
# # NLP Assignment 4

# %% [markdown]
# - Name: Anagha Sarmalkar
# - 800#: 801077504

# %% [markdown]
# ### Import the necessary libraries

# %%
import string 
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize
import boolean
import re
from functools import reduce
from nltk.stem.porter import *
import math

# %% [markdown]
# ### Initialze porter stemmer, stopwords and translator to preprocess the corpus

# %%
ps = PorterStemmer() 
stop_words = set(stopwords.words('english')) 
translator = str.maketrans(string.punctuation, ' '*len(string.punctuation))

# %% [markdown]
# ### Preprocess the corpus
#
# - Clean the text for every document by removing punctuations, stopwords and stemming the words.
# - Tokenize the words and store them in a list referencing the document number in a dictionary.
# - Sort the dictionary in the ascending order of document ids.

# %%
def preprocess(corpus_path):
    corpus={}
    with open("tweets_corpus.txt") as f:
        for line in f:
            key, value=line.split("\t")
            value_list=value.translate(translator).lower().split()
            new_list=[]
            for word in value_list:
                if word not in stop_words:
                    new_list.append(ps.stem(word))
            corpus[int(key)]=new_list
    sorted_corpus = dict(sorted(corpus.items()))
    return sorted_corpus

# %% [markdown]
# ### Load the corpus

# %%
corpus_path="tweets_corpus.txt"
sorted_corpus=preprocess(corpus_path)

# %%
sorted_corpus
# Out:
# {81499877556760576: ['bandag',
#   'paper',
#   'cut',
#   'cheesecak',
#   'dinner',
#   'call',
#   'night',
#   'doin',
#   'big',
#   'nyc'],
#  81500716438523904: ['krispi',
#   'kreme',
#   'strawberri',
#   'trifl',
#   'sinc',
#   'start',
#   'gym',
#   'cri'],
#  81503002321616896: ['bacon',
#   'cheddar',
#   'slider',
#   'top',
#   'w',
#   'fri',
#   'egg',
#   'blue',
#   'chees',
#   'slider',
#   'top',
#   'w',
#   'avocado',
#   'purpl',
#   'cheroke',
#   'tomato'],
#  81507775422791680: ['nacho', 'w', 'chees', 'shirt', 'uggghhh'],
#  81534165975171072: ['aint',
#   'nuffin',
#   'piec',
#   'chees',
#   'without',
#   'corner',
#   'word',
#   'never',
#   'slice',
#   'bitch'],
#  81535634019323904: ['tag',
#   'usernam',
#   'tag',
#   'usernam',
#   'mmmm',
#   'chees',
#   'dream',
#   'squirrel',
#   'burger',
#   'chees'],
#  81577509950459904: ['mmmm', 'chees'],
#  81582996083326976: ['tag',
#   'usernam',
#   '1st',
#   'like',
#   '1',
#   'year',
#   'younger',
#   'u',
#   '2nd',
#   'age',
#   'number',
#   '3rd',
#   'ima',
#   'cater',
#   'ur',
#   'wed',
#   'wit',
#   'patti',
#   'n',
#   'chees'],
#  81587643376336896: ['rt',
#   'tag',
#   'usernam',
#   'want',
#   'steak',
#   'chees',
#   'egg',
#   'roll',
#   'right'],
#  81600113016971264: ['think',
#   'imma',
#   'eat',
#   'cheesecak',
#   'befor',
#   'lay',
#   'havent'],
#  81623945064890368: ['mix',
#   'one',
#   'mostli',
#   'strawberri',
#   'peach',
#   'littl',
#   'white',
#   'cherri',
#   'dr',
#   'pepper',
#   'coke',
#   'etc'],
#  81644157432643584: ['stomach',
#   'yell',
#   'tell',
#   'get',
#   'ass',
#   'nd',
#   'get',
#   'somethin',
#   'eat',
#   'went',
#   'nd',
#   'got',
#   'cheesestick',
#   'nd',
#   'waterbottl'],
#  81656304107651072: ['chocol',
#   'mint',
#   'cooki',
#   'cream',
#   'berri',
#   'strawberri',
#   'chocol',
#   'caramel',
#   'blend',
#   'perfectli',
#   'mouth'],
#  81673244926685184: ['think',
#   'want',
#   'chees',
#   'egg',
#   'pancak',
#   'cook',
#   'gf',
#   'right',
#   'make',
#   'hard',
#   'decis'],
#  81715158593966080: ['tag',
#   'usernam',
#   'total',
#   'also',
#   'good',
#   'fish',
#   'chicken',
#   'veggi',
#   'oh',
#   'dessert',
#   'drizzl',
#   'strawberri',
#   'tart',
#   'parti',
#   'tonight',
#   'c'],
#  81716618236928000: ['tag',
#   'usernam',
#   'want',
#   'get',
#   'strawberri',
#   'cheesecak',
#   'candi',
#   'bear',
#   '2',
#   '38',
#   'expir'],
#  81736742478155778: ['made', 'scrambl', 'egg', 'chees', 'bacon', 'bit'],
#  81842384404623360: ['tag',
#   'usernam',
#   'could',
#   'tri',
#   'great',
#   'haha',
#   'could',
#   'recommend',
#   'get',
#   'strawberri',
#   'one',
#   'that',
#   'fave'],
#  81844590625304576: ['tag',
#   'usernam',
#   'im',
#   '100',
#   'pure',
#   'strawberri',
#   'flavour',
#   'hmmm',
#   'tasti'],
#  82461950231064576: ['beauti',
#   'pink',
#   'colour',
#   'raspberri',
#   'strawberri',
#   'banana',
#   'smoothi'],
#  82650970722533376: ['went',
#   'swim',
#   'ate',
#   'asparagu',
#   'bacon',
#   'egg',
#   'chees',
#   'biscuit',
#   'good',
#   'watch',
#   'date',
#   'night',
#   'good',
#   'tag',
#   'final',
#   'hashtag'],
#  85032815321825280: ['chees',
#   'hashbrown',
#   'turkey',
#   'bacon',
#   'veggi',
#   'tofu',
#   'scrambl',
#   'rice',
#   'french',
#   'toast',
#   'scrambl',
#   'egg',
#   'strawberri',
#   'cantaloup',
#   'tag',
#   'final',
#   'hashtag'],
#  85094773555335168: ['tag',
#   'hashtag',
#   'use',
#   'cream',
#   'chees',
#   'ice',
#   'chocol',
#   'cake',
#   'use',
#   'vanilla',
#   'strawberri'],
#  86441828815089664: ['rt',
#   'tag',
#   'usernam',
#   'rt',
#   'tag',
#   'usernam',
#   'pancak',
#   'bacon',
#   'egg',
#   'w',
#   'chees',
#   'hashbrown',
#   'casserol',
#   'deck',
#   'tag',
#   'hashtag',
#   'want',
#   'sum',
#   'ok',
#   'good']}

# %% [markdown]
# ## 1. Function for Inverted Index
#
# - Every word in the document is referenced by a list of document it appears in.
# - It is stored in a dictionary in the ascending order of keys.

# %%
def inverted_index(corpus):
    vocabulary={}
    for key,value in corpus.items():
        for word in value:
            if word not in vocabulary:
                vocabulary[word]=[]
            if key in vocabulary[word]:
                pass
            else:
                vocabulary[word].append(key)
    sorted_vocab = dict(sorted(vocabulary.items()))
    return sorted_vocab

# %%
sorted_vocab = inverted_index(sorted_corpus)

# %%
sorted_vocab
# Out:
# {'1': [81582996083326976],
#  '100': [81844590625304576],
#  '1st': [81582996083326976],
#  '2': [81716618236928000],
#  '2nd': [81582996083326976],
#  '38': [81716618236928000],
#  '3rd': [81582996083326976],
#  'age': [81582996083326976],
#  'aint': [81534165975171072],
#  'also': [81715158593966080],
#  'asparagu': [82650970722533376],
#  'ass': [81644157432643584],
#  'ate': [82650970722533376],
#  'avocado': [81503002321616896],
#  'bacon': [81503002321616896,
#   81736742478155778,
#   82650970722533376,
#   85032815321825280,
#   86441828815089664],
#  'banana': [82461950231064576],
#  'bandag': [81499877556760576],
#  'bear': [81716618236928000],
#  'beauti': [82461950231064576],
#  'befor': [81600113016971264],
#  'berri': [81656304107651072],
#  'big': [81499877556760576],
#  'biscuit': [82650970722533376],
#  'bit': [81736742478155778],
#  'bitch': [81534165975171072],
#  'blend': [81656304107651072],
#  'blue': [81503002321616896],
#  'burger': [81535634019323904],
#  'c': [81715158593966080],
#  'cake': [85094773555335168],
#  'call': [81499877556760576],
#  'candi': [81716618236928000],
#  'cantaloup': [85032815321825280],
#  'caramel': [81656304107651072],
#  'casserol': [86441828815089664],
#  'cater': [81582996083326976],
#  'cheddar': [81503002321616896],
#  'chees': [81503002321616896,
#   81507775422791680,
#   81534165975171072,
#   81535634019323904,
#   81577509950459904,
#   81582996083326976,
#   81587643376336896,
#   81673244926685184,
#   81736742478155778,
#   82650970722533376,
#   85032815321825280,
#   85094773555335168,
#   86441828815089664],
#  'cheesecak': [81499877556760576, 81600113016971264, 81716618236928000],
#  'cheesestick': [81644157432643584],
#  'cheroke': [81503002321616896],
#  'cherri': [81623945064890368],
#  'chicken': [81715158593966080],
#  'chocol': [81656304107651072, 85094773555335168],
#  'coke': [81623945064890368],
#  'colour': [82461950231064576],
#  'cook': [81673244926685184],
#  'cooki': [81656304107651072],
#  'corner': [81534165975171072],
#  'could': [81842384404623360],
#  'cream': [81656304107651072, 85094773555335168],
#  'cri': [81500716438523904],
#  'cut': [81499877556760576],
#  'date': [82650970722533376],
#  'decis': [81673244926685184],
#  'deck': [86441828815089664],
#  'dessert': [81715158593966080],
#  'dinner': [81499877556760576],
#  'doin': [81499877556760576],
#  'dr': [81623945064890368],
#  'dream': [81535634019323904],
#  'drizzl': [81715158593966080],
#  'eat': [81600113016971264, 81644157432643584],
#  'egg': [81503002321616896,
#   81587643376336896,
#   81673244926685184,
#   81736742478155778,
#   82650970722533376,
#   85032815321825280,
#   86441828815089664],
#  'etc': [81623945064890368],
#  'expir': [81716618236928000],
#  'fave': [81842384404623360],
#  'final': [82650970722533376, 85032815321825280],
#  'fish': [81715158593966080],
#  'flavour': [81844590625304576],
#  'french': [85032815321825280],
#  'fri': [81503002321616896],
#  'get': [81644157432643584, 81716618236928000, 81842384404623360],
#  'gf': [81673244926685184],
#  'good': [81715158593966080, 82650970722533376, 86441828815089664],
#  'got': [81644157432643584],
#  'great': [81842384404623360],
#  'gym': [81500716438523904],
#  'haha': [81842384404623360],
#  'hard': [81673244926685184],
#  'hashbrown': [85032815321825280, 86441828815089664],
#  'hashtag': [82650970722533376,
#   85032815321825280,
#   85094773555335168,
#   86441828815089664],
#  'havent': [81600113016971264],
#  'hmmm': [81844590625304576],
#  'ice': [85094773555335168],
#  'im': [81844590625304576],
#  'ima': [81582996083326976],
#  'imma': [81600113016971264],
#  'kreme': [81500716438523904],
#  'krispi': [81500716438523904],
#  'lay': [81600113016971264],
#  'like': [81582996083326976],
#  'littl': [81623945064890368],
#  'made': [81736742478155778],
#  'make': [81673244926685184],
#  'mint': [81656304107651072],
#  'mix': [81623945064890368],
#  'mmmm': [81535634019323904, 81577509950459904],
#  'mostli': [81623945064890368],
#  'mouth': [81656304107651072],
#  'n': [81582996083326976],
#  'nacho': [81507775422791680],
#  'nd': [81644157432643584],
#  'never': [81534165975171072],
#  'night': [81499877556760576, 82650970722533376],
#  'nuffin': [81534165975171072],
#  'number': [81582996083326976],
#  'nyc': [81499877556760576],
#  'oh': [81715158593966080],
#  'ok': [86441828815089664],
#  'one': [81623945064890368, 81842384404623360],
#  'pancak': [81673244926685184, 86441828815089664],
#  'paper': [81499877556760576],
#  'parti': [81715158593966080],
#  'patti': [81582996083326976],
#  'peach': [81623945064890368],
#  'pepper': [81623945064890368],
#  'perfectli': [81656304107651072],
#  'piec': [81534165975171072],
#  'pink': [82461950231064576],
#  'pure': [81844590625304576],
#  'purpl': [81503002321616896],
#  'raspberri': [82461950231064576],
#  'recommend': [81842384404623360],
#  'rice': [85032815321825280],
#  'right': [81587643376336896, 81673244926685184],
#  'roll': [81587643376336896],
#  'rt': [81587643376336896, 86441828815089664],
#  'scrambl': [81736742478155778, 85032815321825280],
#  'shirt': [81507775422791680],
#  'sinc': [81500716438523904],
#  'slice': [81534165975171072],
#  'slider': [81503002321616896],
#  'smoothi': [82461950231064576],
#  'somethin': [81644157432643584],
#  'squirrel': [81535634019323904],
#  'start': [81500716438523904],
#  'steak': [81587643376336896],
#  'stomach': [81644157432643584],
#  'strawberri': [81500716438523904,
#   81623945064890368,
#   81656304107651072,
#   81715158593966080,
#   81716618236928000,
#   81842384404623360,
#   81844590625304576,
#   82461950231064576,
#   85032815321825280,
#   85094773555335168],
#  'sum': [86441828815089664],
#  'swim': [82650970722533376],
#  'tag': [81535634019323904,
#   81582996083326976,
#   81587643376336896,
#   81715158593966080,
#   81716618236928000,
#   81842384404623360,
#   81844590625304576,
#   82650970722533376,
#   85032815321825280,
#   85094773555335168,
#   86441828815089664],
#  'tart': [81715158593966080],
#  'tasti': [81844590625304576],
#  'tell': [81644157432643584],
#  'that': [81842384404623360],
#  'think': [81600113016971264, 81673244926685184],
#  'toast': [85032815321825280],
#  'tofu': [85032815321825280],
#  'tomato': [81503002321616896],
#  'tonight': [81715158593966080],
#  'top': [81503002321616896],
#  'total': [81715158593966080],
#  'tri': [81842384404623360],
#  'trifl': [81500716438523904],
#  'turkey': [85032815321825280],
#  'u': [81582996083326976],
#  'uggghhh': [81507775422791680],
#  'ur': [81582996083326976],
#  'use': [85094773555335168],
#  'usernam': [81535634019323904,
#   81582996083326976,
#   81587643376336896,
#   81715158593966080,
#   81716618236928000,
#   81842384404623360,
#   81844590625304576,
#   86441828815089664],
#  'vanilla': [85094773555335168],
#  'veggi': [81715158593966080, 85032815321825280],
#  'w': [81503002321616896, 81507775422791680, 86441828815089664],
#  'want': [81587643376336896,
#   81673244926685184,
#   81716618236928000,
#   86441828815089664],
#  'watch': [82650970722533376],
#  'waterbottl': [81644157432643584],
#  'wed': [81582996083326976],
#  'went': [81644157432643584, 82650970722533376],
#  'white': [81623945064890368],
#  'wit': [81582996083326976],
#  'without': [81534165975171072],
#  'word': [81534165975171072],
#  'year': [81582996083326976],
#  'yell': [81644157432643584],
#  'younger': [81582996083326976]}

# %% [markdown]
# ## 2. Function for Merge Algorithm
# - The sample user queries are taken in a list.
# - Every element in the list is tokenized and separated according to the boolean operators that are included.
# - The query is optimized for every AND operation by adding the terms (set.intersection operation) in the increasing order of frequencies.
# - The OR operation is realized by using the set.union operation.

# %%
 def process_query(query_list):   
    operands=['or','not']
    brac_op={}
    for user_query in query_list:
        query = user_query.lower()
        main_query = re.split(r"\s+(?=[^()]*(?:\(|$))", query)
        op=[]
        or_op={}
        and_op={}
        for query in main_query:
            if query in operands:
                op.append(query) 
            else:
                query = query.split('or')
                for sub_query in query: #subqueries to be or-ed
                    sub_query1 = sub_query.split('and')
                    for term in sub_query1: #terms to be and-ed
                        term=term.translate(translator).strip()
                        search = ps.stem(term)
                        if search in sorted_vocab.keys():
                            and_op[search] = sorted_vocab[search]
                        else:
                            and_op[search]=[]
                    and_op = dict(sorted(and_op.items(), key=lambda kv: (len(kv[1]), kv[0])))
                    if 'and' in sub_query:
                        ans = reduce(set.intersection, (set(val) for val in and_op.values()))
                        or_op[sub_query]=ans
                        brac= reduce(set.union, (set(val) for val in or_op.values()))
                    else:
                        brac= reduce(set.union, (set(val) for val in and_op.values()))
        brac_op[user_query]=brac
    return brac_op

# %% [markdown]
# ### Sample queries and their results

# %%
query_list=['(egg AND cheese)',
            '(chocolate AND strawberry)',
            '(eggs AND cheese AND bacon)',
            '(chocolate OR strawberry)',
            '((eggs AND cheese) OR (eggs AND bacon))']

retrieved_docs=process_query(query_list)

# %%
retrieved_docs
# Out:
# {'(egg AND cheese)': {81503002321616896,
#   81587643376336896,
#   81673244926685184,
#   81736742478155778,
#   82650970722533376,
#   85032815321825280,
#   86441828815089664},
#  '(chocolate AND strawberry)': {81656304107651072, 85094773555335168},
#  '(eggs AND cheese AND bacon)': {81503002321616896,
#   81736742478155778,
#   82650970722533376,
#   85032815321825280,
#   86441828815089664},
#  '(chocolate OR strawberry)': {81500716438523904,
#   81623945064890368,
#   81656304107651072,
#   81715158593966080,
#   81716618236928000,
#   81842384404623360,
#   81844590625304576,
#   82461950231064576,
#   85032815321825280,
#   85094773555335168},
#  '((eggs AND cheese) OR (eggs AND bacon))': {81503002321616896,
#   81587643376336896,
#   81673244926685184,
#   81736742478155778,
#   82650970722533376,
#   85032815321825280,
#   86441828815089664}}

# %% [markdown]
# ## 3. Function for TF-IDF Scoring
#
# - Given a query q and a document d, the TF-IDF score of the document has been calculated by summing tf-idf for every term t in q.
# - TF-IDF displays the importance of the query terms in the document.
# - TF-IDF is 0 for the terms not present in the document.

# %%
def tf_idf_scoring(query_list):
    operands=['or','and']
    query_terms=[]
    doc_score={}
    query_doc={}
    query_sample=query_list[0]
    query = query_sample.lower().translate(translator).split()
    for term in query:
        if term not in operands:
            query_terms.append(ps.stem(term))
    # for value in sample[query_sample]:
    for value in sorted_corpus.keys():
        term_doc_freq=len(sorted_corpus[value])
        tf_idf=0
        for term in query_terms:
            term_count=sorted_corpus[value].count(term)
            tf = (term_count/term_doc_freq)
            idf = math.log(len(sorted_corpus)/len(sorted_vocab[term]))
            tf_idf=tf_idf+(tf*idf)
        doc_score[value]=["Score:", tf_idf]
    query_doc[query_sample]=doc_score
#     print(query_doc)
    return query_doc

# %%
sample_query=['(egg AND cheese)']
tfidf = tf_idf_scoring(sample_query)

# %%
tfidf
# Out:
# {'(egg AND cheese)': {81499877556760576: ['Score:', 0.0],
#   81500716438523904: ['Score:', 0.0],
#   81503002321616896: ['Score:', 0.11532800963619008],
#   81507775422791680: ['Score:', 0.12262089457728179],
#   81534165975171072: ['Score:', 0.06131044728864089],
#   81535634019323904: ['Score:', 0.12262089457728179],
#   81577509950459904: ['Score:', 0.30655223644320445],
#   81582996083326976: ['Score:', 0.030655223644320446],
#   81587643376336896: ['Score:', 0.20502757268656013],
#   81600113016971264: ['Score:', 0.0],
#   81623945064890368: ['Score:', 0.0],
#   81644157432643584: ['Score:', 0.0],
#   81656304107651072: ['Score:', 0.0],
#   81673244926685184: ['Score:', 0.16774983219809467],
#   81715158593966080: ['Score:', 0.0],
#   81716618236928000: ['Score:', 0.0],
#   81736742478155778: ['Score:', 0.30754135902984014],
#   81842384404623360: ['Score:', 0.0],
#   81844590625304576: ['Score:', 0.0],
#   82461950231064576: ['Score:', 0.0],
#   82650970722533376: ['Score:', 0.11532800963619008],
#   85032815321825280: ['Score:', 0.10854400906935538],
#   85094773555335168: ['Score:', 0.05573677026240081],
#   86441828815089664: ['Score:', 0.09226240770895205]}}

# %% [markdown]
# ### Document 81736742478155778 has the highest TF-IDF score for the query (egg AND cheese)
